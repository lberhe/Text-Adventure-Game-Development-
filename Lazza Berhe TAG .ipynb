# %%
"""
Created on Sun Oct 18 10:34:00 2020

@author: Lazza.Berhe
"""

"""
    DocString:
    
    A) Introduction:
    This game was created inorder to challenge your brain against simple questions that may seem complex while putting you under pressure as the Death God is trying to take you away. It consists of three stages, and also has defined functions
    for stages, giving up, and failing also includes a bonus. This game requires some thought, and being patient will be helpful.
    
    Your goal is to get past the the three rounds without either failing or giving up. If you manage to complete all three stages as well as the bonus, you will be able to be revived and will be granted one wish. 
    B) Known Bugs and/or Errors:
    None.
    
"""


import os #imported os so that exit() can be used 
def stage1():#this is the first stage function
    print("Are you ready for stage1!\n")
    input(prompt='<Press any key to continue>\n')
    choice_1=["Feb","February","feb","One", "1", "B","b"]
    answer1=input(prompt="How many months have 28 days?\nA- All\nB- 1\nC- 0\nD- Give-Up\n> ")
    if answer1 in choice_1 :
            print("That's correct.")
            print("Would you like to continue? Since you have answered correctly I wont torture you just yet")
            print("1- yes")
            print("2- no, I give up ")
            choice = input("> ")
     
            list_choice_1 = ["Yes", "yes", "continue", "Continue", "1", "One"]
            if choice in list_choice_1:
                stage2()
            else:
                giveup()
                
    else:
        
        fail()
        stage1()
        
def stage2():#this is the second stage function
    print("Are you ready for stage2!\n")
    input(prompt='<Press any key to continue>\n')
    choice_2_1=["Seven","seven","7", "3", "Three", "C","c"]
    answer_2_1=input(prompt= "I am an odd number. Take away one letter and I become even. What number am I?\n1. Five\n2. 6\n3. Seven\n4. 7\n> ")
    if answer_2_1 in choice_2_1:
        print("That's correct.")
        print("Would you like to continue? Since you have answered correctly I wont torture you just yet")
        print("1- yes")
        print("2- no, i give up ")
        choice = input("> ")
        if choice == '1':
            print("Here comes question numberrrrr twoooo for stage #2 \U0001f600 ")
            choice_2_2=["Bottle", "bottle", "2", "Two", "two"]
            answer2_2=input(prompt= " What has a neck but no head?\n1. Neckless Swordsman\n2. Bottle\n3. HourGlass\n4. Bulb\n> ")
            if answer2_2 in choice_2_2:
                print("That's correct.")
                print("Would you like to continue? Since you have answered correctly I wont torture you just yet")
                print("1- yes")
                print("2- no, i give up ")
                choice = input("> ")
                if choice == '1' or 'yes':
                    stage3()
                else:
                    giveup()
            else:
                fail()
                stage2()
                
        else:
            giveup()
    else:
        fail()
        stage2()
        
def stage3():#this is the third stage function
    print("Are you ready for stage3!\n")
    input(prompt='<Press any key to continue>\n')
    choice_3_1=["Proprietary", "proprietary", "3", "Three", "C","c"]
    answer3_1=input(prompt= "Which one of the following is correct: \n1. Properetry\n2. Propriatory\n3. Proprietary\n4. Proprietory\n> ")
    if answer3_1 in choice_3_1:
        print("That's correct.")
        print("Would you like to continue? Since you have answered correctly I wont torture you just yet")
        print("1- yes")
        print("2- no, I give up ")
        choice = input("> ")
        if choice == '1':
            print("Here comes the second question of stage 3 ")
            choice_3_2=["2", "Two", "two", "B","b"]
            answer3_2=input(prompt= "A fool's paradise meanining is: \n1. paradise of idiots\n2. a state of illusory happiness\n3. to live in the past\n4. to have happy dreams\n> ")
            if answer3_2 in choice_3_2:
                print("That's correct.")
                print("Would you like to continue? Since you have answered correctly I wont torture you just yet")
                print("1- yes")
                print("2- no, I give up ")
                choice = input("> ")
                if choice == '1':
                    print("Here comes the third question of stage 3 ")
                    choice_3_3=["Clear", "clear", "4", "Four", "four","D","d"]
                    answer3_3=input("last question - Antonym of OBSCURE is\n1. Suitable\n2. Apt\n3. Thalamus\n4. Clear\n> ")
                    if answer3_3 in choice_3_3:
                        print("That's correct.")
                        print("You have answered every question correctly , I have a bonus question and if answered correctly I will  fullfill your 1 wish and if failed you will die and I will not torture you in hell")
                        print("so.. do you do you want to try?")
                        print("1- yes")
                        print("2- no, I dont want bonus")
                        choice = input("> ")
                        if choice == '1':
                            bonus()
                        else:
                            print("You are worthy to be reborn GoodLuck HUMAN AHAHAHAHAHAAHAHHA!!!!!")
                    else:
                        fail()
                        stage3()
                else:
                    giveup()
            else:
                fail()
                stage3()
        
        else:
            giveup()
    else:
        fail()
        stage3()
        
def bonus():#bonus question function
    chances=3;
    print("In the bonus round there will be no hint for you but there will be 3 chances")
    while(chances>0):
        ans= input("If a plane crashes on the border between the United States and Canada, where do they bury the survivors?")
        if "no" or "not" or "don't" in ans:
            print("HAHAHA CORRECT, YOUR INTELLIGENCE IS COMMENDABLE CONGRATULATIONS I WILL SAVE YOU AND FULLFILL YOUR WISH\U0001f600 ")
            break;
        else:
            chances-=1
            print("WRONG ANSWER!")
            if(chances ==0):
                print("HAHAHAHA!!!! GRIDDY HUMAN YOU WILL DIE NEVER TO REINCARNATE !!!!!!!!")
                input(prompt='<You Died,Press any key to exit>\n') 
    
def giveup():#giveup function
    print("HAHAHA.. NICE DECISION\U0001F614 ")
    input(prompt='<You Died,Press any key to exit>\n')    
       
def fail():#this is fail func
    global name
    print("\n\n",name," you've failed!Do you want to try again?? If yes type yes, if no press any key!")
    check=input(prompt="")
    check=str(check)
    
    fl_lst=["yes"]
    if check in fl_lst:
        print("letsssss tryy this againn")
    else: 
        os._exit(1)
    
    
        
        
        
name=input(prompt= "WELCOME USER!! PLEASE ENTER YOUR NAME: ")
print("Hi ",name,end="\U0001f600, ")
print("""You have been killed in an accident and death god has come to take you. 
You try to stop him from taking you. 
He agrees on one condition.. that you answer all of his questions correctly.. if you can 
answer them he will revive you and if failed..""")
print("\n\t\t\t he \n\t\t\t\t will \n\t\t\t\t\t",
      "torture \n\t\t\t\t\t\t you \n\t\t\t\t\t\t\t in \n\t\t\t\t\t\t\t\t",
      "hell! \n\t\t\t\t\t\t\t\t\t")
stage1()#call stage 1 func
